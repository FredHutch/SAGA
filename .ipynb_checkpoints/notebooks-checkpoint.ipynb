# %% [markdown]
# ## What is the role of SAGA in transcription initiation?
#
# Linda carried out PolII-ChIP experiments of SAGA subunits.
# In each experiment, cells were grown in YPD, and 3IAA (degron inducer) or DMSO (control, should be same as nothing) were added to the media.
# Each experiment has a biological replicate or two. Some experiments have Input (control for intrinsically noisy regions) and technical replicates.
#
# Index of experiments:
# * [Spt8 degron](#med8)
# * [Spt8_3 double degron](#med8_3)

# %%
# %pylab inline
import pandas as pd
import numpy as np
import os,re
from time import time

# To run limma_Rscript
import subprocess
runLimma = 'Rscript'
path2script = '../runLimma.R'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# I might end up using normalization by spike in ONLY...
def spike(filename):
    pombe = filename[:-8] + 'pombe.sam'
    return sum([1 for i in open(filename) if i[0]!='@'])

# This is the data that I will load on limma for the empirical bayes.
def limado(filename):
    df = pd.read_csv(filename, index_col=0)
    M = df.loc[-50:250].idxmax()
    v, k = [], []

    for i in M.index:
        m = M.loc[i]
        v.append(df.loc[m-50:m+50, i].sum())
        k.append(i)
        
    # finally also make the profile to have it handy
    profile = df.mean(axis=1)
    return pd.DataFrame(v, index=k) / spike(filename), profile

# %% [markdown]
# ### Spt8 degron <a class="anchor" id=med8></a>

# %%
Path = '/fh/scratch/delete30/hahn_s/aerijman/SAGA/spt8/'

dmso1, dmso2, _3iaa1, _3iaa2 = [[Path+j+i for i in os.listdir(Path+j) 
                                 if re.search("Sc..mtgn$", i)][0] for j in ['1_Sample_161_Spt8_deg_YPD_DMSO_A/',
                                                                            '3_Sample_163_Spt8_deg_YPD_DMSO_B/',
                                                                            '2_Sample_162_Spt8_deg_YPD_3IAA_A/',
                                                                            '4_Sample_164_Spt8_deg_YPD_3IAA_B/']]
c1, c2, t1, t2 = [limado(i) for i in [dmso1, dmso2, _3iaa1, _3iaa2]]


# save file for future use if needed.
Spt8deg = pd.concat([i[0] for i in [c1,c2,t1,t2]], axis=1)
Spt8deg.columns = ['c1','c2','t1','t2']
Spt8deg.to_csv('./med8_deg_pre_limma.csv')

# %%
plt.figure(figsize=(5,5))
[eval(i)[1].plot(label=i) for i in ['c1','c2','t1','t2']]
plt.legend(loc=(1.04,0)); plt.grid(); plt.title('Spt8')
# Out:
# Text(0.5,1,'Spt8')

# %%
# Run limma from R

# Variable number of args in a list
args = ['Spt8_deg_pre_limma.csv', '2', '2', 'Spt8_deg_limma.jpg']

# Build subprocess command
cmd = [runLimma, path2script] + args

# check_output will run the command and store to result
volcano = subprocess.check_output(cmd, universal_newlines=True)

# %% [markdown]
# #### Spt8 degron experiments were very unsuccesful. We try with the other degron strains and with the double degrons
#
# ### Spt8_3 double degron <a class="anchor" id="med8_3"></a>

# %%
Path = '/fh/scratch/delete30/hahn_s/aerijman/SAGA/spt_8_3/'

c1,t1,t2,t3,c2,c3,c4,c5,t4,c6,t5,t6,t7,t8,c7,c8 = [[Path+j+i for i in os.listdir(Path+j) if re.search("Sc..mtgn$", i)][0] for j in
                                                                                                   ['10_Sample_254C_Spt8_3_YPD_DMSO_A/',
                                                                                                    '11_Sample_255A_Spt8_3_YPD_3IAA_B/',
                                                                                                    '12_Sample_255B_Spt8_3_YPD_3IAA_B/',
                                                                                                    '13_Sample_255C_Spt8_3_YPD_3IAA_B/',
                                                                                                    '14_Sample_256A_Spt8_3_YPD_DMSO_B/',
                                                                                                    '15_Sample_256B_Spt8_3_YPD_DMSO_B/',
                                                                                                    '16_Sample_256C_Spt8_3_YPD_DMSO_B/',
                                                                                                    '1_Sample_217_Spt3_Spt8_deg_YPD_DMSO_A/',
                                                                                                    '2_Sample_218_Spt3_Spt8_deg_YPD_3IAA_A/',
                                                                                                    '3_Sample_219_Spt3_Spt8_deg_YPD_DMSO_B/',
                                                                                                    '4_Sample_220_Spt3_Spt8_deg_YPD_3IAA_B/',
                                                                                                    '5_Sample_253A_Spt8_3_YPD_3IAA_A/',
                                                                                                    '6_Sample_253B_Spt8_3_YPD_3IAA_A/',
                                                                                                    '7_Sample_253C_Spt8_3_YPD_3IAA_A/',
                                                                                                    '8_Sample_254A_Spt8_3_YPD_DMSO_A/',
                                                                                                    '9_Sample_254B_Spt8_3_YPD_DMSO_A/']]

c1,c2,c3,c4,c5,c6,c7,c8,t1,t2,t3,t4,t5,t6,t7,t8 = [limado(i) for i in [c1,c2,c3,c4,c5,c6,c7,c8,t1,t2,t3,t4,t5,t6,t7,t8]]

# %%
plt.figure(figsize=(5,5))
cols = ['b']*8 + ['r']*8
ls = ['--']*8 + ['-']*8
[eval(i)[1].plot(label=i, c=cols[n], ls=ls[n]) for n,i in enumerate(['c'+str(i) for i in np.arange(1,9)] + ['t'+str(i) for i in np.arange(1,9)])]
plt.legend(loc=(1.04,0)); plt.grid(); plt.title('Spt8_3');

# %% [markdown]
# I already know that c5,t4,c6,t5 were done in a separate date and I can avoid using this files (batch effect)

# %%
# save file for future use if needed.
Spt8_3deg = pd.concat([i[0] for i in [c1,c2,c3,c4,c7,c8,t1,t2,t3,t6,t7,t8]], axis=1)
Spt8_3deg.columns = ['c1','c2','c3','c4','c7','c8','t1','t2','t3','t6','t7','t8']
Spt8_3deg.to_csv('./Spt8_3_deg_pre_limma.csv')

# %%
# Run limma from R

# Variable number of args in a list
args = ['Spt8_3_deg_pre_limma.csv', '6', '6', '../figures/Spt8_3_deg_volcano.jpg']

# Build subprocess command
cmd = [runLimma, './shortScript.R'] + args

# check_output will run the command and store to result
volcano = subprocess.check_output(cmd, universal_newlines=True)

# %% [markdown]
# ![image](../figures/med8_3_deg_volcano.jpg)

# %%
Spt8_3 = pd.read_csv('./volcano8_3_deg_pre.csv', index_col=0)

positives = Spt8_3[(Spt8_3['adj.P.Val']<0.05) & (Spt8_3.logFC>np.log(1.5))]
negatives = Spt8_3[(Spt8_3['adj.P.Val']<0.05) & (Spt8_3.logFC<-np.log(1.5))]

len(set(negatives.index) | set(positives.index))
# Out:
# 270
